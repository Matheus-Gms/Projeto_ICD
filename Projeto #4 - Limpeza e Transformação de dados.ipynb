# %% [markdown]
# # Projeto #4 - Limpeza e Transformação de dados

# %% [markdown]
# ### Não foi necessário a limpeza e/ou transformação dos dados do nosso dataset nessa parte do projeto.

# %% [markdown]
# #### O grupo não utilizou de um dataset já pronto, ao invvés disso optamos pela criação do nosso  próprio dataset (Dados dos principais times do brasileirão nos últimos 5 anos - 2015/2019). A partir disso, coletamos os dados dos times (por ano) diretamente do site da CBF, analisano os times nos anos de 2015 a 2019, e nas séries A, B, C e D. Com todos os dados em mãos, criamos uma planilha no excel e em seguida geramos o arquivo .csv . A partir disso, pode-se dizer que a limpeza e a transformação dos dados foram feitos diretamente durante todo o processo da coleta dos mesmos.

# %% [markdown]
# #### O dataset criado pode ser visualizado abaixo

# %%
import pandas as pd

# %%
brasileirao_df = pd.read_csv("dataset/brasileirao_2015_2019.csv")
brasileirao_df
# Out:
#              TIMES        REGIÃO   ANO SÉRIE  PTS   J   V   E   D  GP  GC  SG  \
# 0              Abc      Nordeste  2019     C   18  18   4   6   8  19  22  -3
# 1     América - MG       Sudeste  2019     B   61  38  17  10  11  42  34   8
# 2    América Natal      Nordeste  2019     D   14   6   4   2   0  20   1  19
# 3              Asa      Nordeste  2019     D   13   6   4   1   1   8   5   1
# 4    Atlético - GO  Centro-Oeste  2019     B   62  38  15  17   6  44  29  15
# ..             ...           ...   ...   ...  ...  ..  ..  ..  ..  ..  ..  ..
# 290          Sport      Nordeste  2015     A   59  38  15  14   9  53  38  15
# 291          Treze      Nordeste  2015     D   15   8   4   3   1  11   5   6
# 292          Vasco       Sudeste  2015     A   41  38  10  11  17  28  54 -26
# 293      Vila Nova  Centro-Oeste  2015     C   44  24  13   5   6  31  16  15
# 294        Vitória      Nordeste  2015     B   66  38  19   9  10  58  40  18
#
#       CA  CV
# 0     55   2
# ...
